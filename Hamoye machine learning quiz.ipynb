# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel(r'/content/drive/MyDrive/energydata_complete.xlsx')

# %%
part_df = df[["T6", "T2"]]

# %%
y = df.T6

# %%
x = part_df[["T2"]]

# %%
from sklearn import metrics

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score

# %%
linr_model = LinearRegression().fit(x, y)

# %%
linr_model
# Out:
# LinearRegression()

# %%
linr_model.coef_
# Out:
# array([2.22506139])

# %%
linr_model.intercept_
# Out:
# -37.3495226384453

# %%
r2_score(

    y_true = part_df.T6, 

    y_pred = linr_model.predict(part_df[["T2"]])

)
# Out:
# 0.6418990830855485

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(
     y_true = part_df.T6, 

    y_pred = linr_model.predict(part_df[["T2"]])

)

# %%
print(mae)
# Out:
# 2.838473720687602

# %%
rss = np.sum(np.square(
    y_true = part_df.T6, 

    y_pred = linr_model.predict(part_df[["T2"]])

))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-fc0947c41601> in <module>
# ----> 1 rss = np.sum(np.square(
#       2     y_true = part_df.T6,
#       3
#       4     y_pred = linr_model.predict(part_df[["T2"]])
#       5
#
# TypeError: square() takes from 1 to 2 positional arguments but 0 were given

# %%
df1 = df.drop(columns =['date', 'lights'])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
normalised_df1 = pd.DataFrame(scaler.fit_transform(df1))

# %%
The target variable is “Appliances”. Use a 70-30 train-test set split with a random state of 42 (for reproducibility). Run a multiple linear regression using the training set and evaluate your model on the test set

# %%
heating_target = normalised_df1['Appliance']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-1051a08a0b4a> in <module>
# ----> 1 heating_target = normalised_df1['Appliance']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'Appliance'

# %%
features_df1 = normalised_df1.drop(columns=['date', 'lights'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-7ba032a3661d> in <module>
# ----> 1 features_df1 = normalised_df1.drop(columns=['date', 'lights'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
normalised_df1['Appliance']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-d9de004c5a19> in <module>
# ----> 1 normalised_df1['Appliance']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'Appliance'

# %%
features_df1 = normalised_df1.drop(columns=['Appliances'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-924d1e719045> in <module>
# ----> 1 features_df1 = normalised_df1.drop(columns=['Appliances'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(normalised_df1, 'Appliances',
test_size=0.3, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-f79fa011310c> in <module>
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(normalised_df1, 'Appliances',
#       2 test_size=0.3, random_state=42)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# ...

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-cc15428950ce> in <module>
# ----> 1 linear_model.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
predicted_values = linear_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-df535f1d5ffa> in <module>
# ----> 1 predicted_values = linear_model.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(y_test, predicted_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-81650c31ffe2> in <module>
# ----> 1 mae = mean_absolute_error(y_test, predicted_values)
#
# NameError: name 'y_test' is not defined

# %%
round(mae, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-d328e19231a8> in <module>
# ----> 1 round(mae, 3)
#
# NameError: name 'mae' is not defined

# %%
import numpy as np

# %%
rss = np.sum(np.square(y_test - predicted_values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-c3ff7a1fbc5c> in <module>
# ----> 1 rss = np.sum(np.square(y_test - predicted_values))
#
# NameError: name 'y_test' is not defined

# %%
round(rss, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-600b0afbe578> in <module>
# ----> 1 round(rss, 3)
#
# NameError: name 'rss' is not defined

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-e1edb2a09ae3> in <module>
# ----> 1 rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
#
# NameError: name 'y_test' is not defined

# %%
round(rmse, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-9c734e06b315> in <module>
# ----> 1 round(rmse, 3)
#
# NameError: name 'rmse' is not defined

# %%
from sklearn.metrics import r2_score

# %%
r2_score = r2_score(y_test, predicted_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-b2eae25188b4> in <module>
# ----> 1 r2_score = r2_score(y_test, predicted_values)
#
# NameError: name 'y_test' is not defined

# %%
round(r2_score, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7fb72cdd6554> in <module>
# ----> 1 round(r2_score, 3)
#
# TypeError: type function doesn't define __round__ method

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge(alpha=0.4)

# %%
ridge_reg.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-c14a8cfb6df9> in <module>
# ----> 1 ridge_reg.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(part_df[["T2"]], df.T6, test_size=0.33, random_state=42)

# %%
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso(alpha=0.001)

# %%
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)
